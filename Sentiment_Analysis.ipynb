# %%
import pandas as pd
from DataUtility import dataUtils, preProcessing, textVectorizer
# Out:
# [nltk_data] Downloading package punkt to /Users/jeeva/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/jeeva/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/jeeva/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     /Users/jeeva/nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!

# %%
dtUtils = dataUtils()
preProcess = preProcessing()
textVector = textVectorizer()

# %%
google_review_data = dtUtils.GetGoogleReviewData()
# Out:
# /Users/jeeva/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
# [10000 rows x 8 columns]

# %%
google_review_data = preProcess.removeEmptyReview(google_review_data)

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
# [6274 rows x 8 columns]

# %%
preProcess.HandleTranslatedData(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["processed_review"]  = data['text'].apply(lambda x:remove_original(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review
# 0     I have been with Sara as my Agent for many yea...
# 1     I went to this allstate because I needed a new...
# 2     Everyone at this office is great!  They make m...
# 3                                         Great service
# 4                                              Friendly
# ...                                                 ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...
# 9996             Pastor Valerie taught a awesome  word.
# 9997  Love the worship experience. The preached word...
# 9998        Went to afternoon Bible study with my mommy
# 9999                             Great place to worship
#
# [6274 rows x 9 columns]

# %%
preProcess.handlePunctuation(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['processed_review'] = data['processed_review'].apply(lambda x: remove_punctuation(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review
# 0     I have been with Sara as my Agent for many yea...
# 1     I went to this allstate because I needed a new...
# 2     Everyone at this office is great  They make me...
# 3                                         Great service
# 4                                              Friendly
# ...                                                 ...
# 9995  I love my pastor Pastor Elder Valerie Bennett ...
# 9996              Pastor Valerie taught a awesome  word
# 9997  Love the worship experience The preached word ...
# 9998        Went to afternoon Bible study with my mommy
# 9999                             Great place to worship
#
# [6274 rows x 9 columns]

# %%
preProcess.DoLowerCase(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['processed_review'] = data['processed_review'].apply(lambda x: x.lower())

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review
# 0     i have been with sara as my agent for many yea...
# 1     i went to this allstate because i needed a new...
# 2     everyone at this office is great  they make me...
# 3                                         great service
# 4                                              friendly
# ...                                                 ...
# 9995  i love my pastor pastor elder valerie bennett ...
# 9996              pastor valerie taught a awesome  word
# 9997  love the worship experience the preached word ...
# 9998        went to afternoon bible study with my mommy
# 9999                             great place to worship
#
# [6274 rows x 9 columns]

# %%
preProcess.removeEmoji(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['processed_review'] = data['processed_review'].apply(lambda x: remove_emojis(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review
# 0     i have been with sara as my agent for many yea...
# 1     i went to this allstate because i needed a new...
# 2     everyone at this office is great  they make me...
# 3                                         great service
# 4                                              friendly
# ...                                                 ...
# 9995  i love my pastor pastor elder valerie bennett ...
# 9996              pastor valerie taught a awesome  word
# 9997  love the worship experience the preached word ...
# 9998        went to afternoon bible study with my mommy
# 9999                             great place to worship
#
# [6274 rows x 9 columns]

# %%
preProcess.handleURLAndHTMLAndSpecialCharacter(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['processed_review'] = data['processed_review'].apply(lambda x:remove_url_html_spc(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review
# 0     i have been with sara as my agent for many yea...
# 1     i went to this allstate because i needed a new...
# 2     everyone at this office is great they make me ...
# 3                                         great service
# 4                                              friendly
# ...                                                 ...
# 9995  i love my pastor pastor elder valerie bennett ...
# 9996               pastor valerie taught a awesome word
# 9997  love the worship experience the preached word ...
# 9998        went to afternoon bible study with my mommy
# 9999                             great place to worship
#
# [6274 rows x 9 columns]

# %%
preProcess.handleNumericValue(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['processed_review'] = data['processed_review'].apply(lambda x: replace_numbers_with_words(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review
# 0     i have been with sara as my agent for many yea...
# 1     i went to this allstate because i needed a new...
# 2     everyone at this office is great they make me ...
# 3                                         great service
# 4                                              friendly
# ...                                                 ...
# 9995  i love my pastor pastor elder valerie bennett ...
# 9996               pastor valerie taught a awesome word
# 9997  love the worship experience the preached word ...
# 9998        went to afternoon bible study with my mommy
# 9999                             great place to worship
#
# [6274 rows x 9 columns]

# %%
preProcess.tokenizeText(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['processed_review'] = data['processed_review'].apply(lambda x: word_tokenize(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review
# 0     [i, have, been, with, sara, as, my, agent, for...
# 1     [i, went, to, this, allstate, because, i, need...
# 2     [everyone, at, this, office, is, great, they, ...
# 3                                      [great, service]
# 4                                            [friendly]
# ...                                                 ...
# 9995  [i, love, my, pastor, pastor, elder, valerie, ...
# 9996        [pastor, valerie, taught, a, awesome, word]
# 9997  [love, the, worship, experience, the, preached...
# 9998  [went, to, afternoon, bible, study, with, my, ...
# 9999                        [great, place, to, worship]
#
# [6274 rows x 9 columns]

# %%
preProcess.handleStopWords(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['processed_review'] = data['processed_review'].apply(lambda x: remove_stopwords(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review
# 0     [sara, agent, many, years, always, get, great,...
# 1     [went, allstate, needed, new, agent, went, saw...
# 2     [everyone, office, great, make, feel, like, im...
# 3                                      [great, service]
# 4                                            [friendly]
# ...                                                 ...
# 9995  [love, pastor, pastor, elder, valerie, bennett...
# 9996           [pastor, valerie, taught, awesome, word]
# 9997  [love, worship, experience, preached, word, aw...
# 9998             [went, afternoon, bible, study, mommy]
# 9999                            [great, place, worship]
#
# [6274 rows x 9 columns]

# %%
preProcess.handleLemmatizer(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['processed_review'] = data['processed_review'].apply(lambda x: lemmatizer(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review
# 0     [sara, agent, many, year, always, get, great, ...
# 1     [went, allstate, needed, new, agent, went, saw...
# 2     [everyone, office, great, make, feel, like, im...
# 3                                      [great, service]
# 4                                            [friendly]
# ...                                                 ...
# 9995  [love, pastor, pastor, elder, valerie, bennett...
# 9996           [pastor, valerie, taught, awesome, word]
# 9997  [love, worship, experience, preached, word, aw...
# 9998             [went, afternoon, bible, study, mommy]
# 9999                            [great, place, worship]
#
# [6274 rows x 9 columns]

# %%
preProcess.handleNegation(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['processed_review'] = data['processed_review'].apply(lambda x: handle_negate_text(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review
# 0     [sara, agent, many, year, always, get, great, ...
# 1     [went, allstate, needed, new, agent, went, saw...
# 2     [everyone, office, great, make, feel, like, im...
# 3                                      [great, service]
# 4                                            [friendly]
# ...                                                 ...
# 9995  [love, pastor, pastor, elder, valerie, bennett...
# 9996           [pastor, valerie, taught, awesome, word]
# 9997  [love, worship, experience, preached, word, aw...
# 9998             [went, afternoon, bible, study, mommy]
# 9999                            [great, place, worship]
#
# [6274 rows x 9 columns]

# %%
preProcess.addSentiwordAnalysis(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sentiment'] = data['processed_review'].apply(lambda x: calculate_sentiment(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review sentiment
# 0     [sara, agent, many, year, always, get, great, ...  Positive
# 1     [went, allstate, needed, new, agent, went, saw...  Positive
# 2     [everyone, office, great, make, feel, like, im...  Positive
# 3                                      [great, service]  Positive
# 4                                            [friendly]  Positive
# ...                                                 ...       ...
# 9995  [love, pastor, pastor, elder, valerie, bennett...  Positive
# 9996           [pastor, valerie, taught, awesome, word]  Positive
# 9997  [love, worship, experience, preached, word, aw...  Positive
# 9998             [went, afternoon, bible, study, mommy]  Positive
# 9999                            [great, place, worship]  Positive
#
# [6274 rows x 10 columns]

# %%
preProcess.joinTextData(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['processed_review'] = data['processed_review'].apply(lambda x: ' '.join(x))

# %%
google_review_data
# Out:
#            user_id              name           time  rating  \
# 0     1.149975e+20           Deb Mae  1611524448905       5
# 1     1.046177e+20      sherry stone  1574805324619       1
# 2     1.064380e+20     Shannon Kropp  1455651168542       5
# 3     1.053143e+20           M A T T  1595369812147       5
# 4     1.075909e+20      Not the Mama  1593635254254       5
# ...            ...               ...            ...     ...
# 9995  1.031211e+20  Darlene Stephens  1568558248148       5
# 9996  1.099381e+20     tamiesha frye  1562607218630       5
# 9997  1.067955e+20   Nan Springfield  1507630294460       5
# 9998  1.087718e+20            D Shan  1538609058076       4
# 9999  1.058784e+20      Eunice Green  1548632172166       5
#
#                                                    text  pics  \
# 0     I have been with Sara as my Agent for many yea...  None
# 1     I went to this allstate because I needed a new...  None
# 2     Everyone at this office is great!  They make m...  None
# 3                                         Great service  None
# 4                                              Friendly  None
# ...                                                 ...   ...
# 9995  I love my pastor, Pastor Elder Valerie Bennett...  None
# 9996             Pastor Valerie taught a awesome  word.  None
# 9997  Love the worship experience. The preached word...  None
# 9998        Went to afternoon Bible study with my mommy  None
# 9999                             Great place to worship  None
#
#                                                    resp  \
# 0     {'time': 1611589883844, 'text': 'Deb,  Thank y...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                     gmap_id  \
# 0     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 1     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 2     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 3     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# 4     0x883b4dcfa112c3f7:0xa893bca9bab5ec71
# ...                                     ...
# 9995  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9996  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9997  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9998  0x8824cc0931a4f903:0x81b6402a3ece92d0
# 9999  0x8824cc0931a4f903:0x81b6402a3ece92d0
#
#                                        processed_review sentiment
# 0     sara agent many year always get great service ...  Positive
# 1     went allstate needed new agent went saw two pe...  Positive
# 2     everyone office great make feel like important...  Positive
# 3                                         great service  Positive
# 4                                              friendly  Positive
# ...                                                 ...       ...
# 9995  love pastor pastor elder valerie bennett hopp ...  Positive
# 9996                 pastor valerie taught awesome word  Positive
# 9997  love worship experience preached word awesome ...  Positive
# 9998                   went afternoon bible study mommy  Positive
# 9999                                great place worship  Positive
#
# [6274 rows x 10 columns]

# %%
tfidf_matrix = textVector.handleTFIDFVectorizer(google_review_data)

# %%
tfidf_matrix
# Out:
# <6274x9561 sparse matrix of type '<class 'numpy.float64'>'
# 	with 90937 stored elements in Compressed Sparse Row format>

# %%
count_matrix = textVector.bagOfWords(google_review_data)

# %%
count_matrix
# Out:
# <6274x9561 sparse matrix of type '<class 'numpy.int64'>'
# 	with 90937 stored elements in Compressed Sparse Row format>

# %%
Spacy_Embeddings = textVector.spacyWordEmbeddings(google_review_data)

# %%
Spacy_Embeddings
# Out:
# 0       [0.12639438, -0.29082587, -0.1048563, -0.22346...
# 1       [0.027422484, -0.25994802, 0.115542084, 0.2812...
# 2       [0.09407043, -0.3955074, 0.0038479806, 0.06397...
# 3       [-0.5226821, -0.9199767, -0.601419, 0.70037705...
# 4       [-1.3199675, -1.1884059, -1.2538893, 0.1586274...
#                               ...
# 9995    [-0.7454406, -0.9545928, 0.041035943, 0.197512...
# 9996    [-0.2394093, -0.59194547, -0.25882536, 0.18151...
# 9997    [-0.26938778, -0.5179119, 0.16029768, 0.239885...
# 9998    [-0.16687137, -0.646795, 0.07326933, -0.114565...
# 9999    [-0.24085064, -0.7542022, -0.15067442, 0.44298...
# Name: processed_review, Length: 6274, dtype: object

# %%
pytorch_word2vec_matrix = textVector.pytorchWord2VecEmbedding(google_review_data)
# Out:
# /Users/jeeva/Documents/SentimentAnalysis1/DataUtility.py:228: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_1aidzjezue/croot/pytorch_1687856425340/work/torch/csrc/utils/tensor_new.cpp:248.)
#   word2vec_matrix = torch.Tensor([word2vec_model.wv[word] for sentence in sentences for word in sentence])

# %%
pytorch_word2vec_matrix
# Out:
# tensor([[-0.1313,  0.0742,  0.0990,  ...,  0.0285, -0.0176,  0.3644],
#         [-0.1467, -0.1127, -0.2090,  ..., -0.1397, -0.0429, -0.1746],
#         [ 0.0990,  0.0851,  0.4223,  ..., -0.0500, -0.0070, -0.0041],
#         ...,
#         [-0.1964,  0.0891,  0.1321,  ...,  0.0060, -0.0197, -0.5313],
#         [ 0.4060, -0.0831,  0.1687,  ..., -0.0295, -0.0857,  0.0081],
#         [ 0.1960, -0.1047, -0.1190,  ...,  0.0928,  0.0859,  0.4802]])

# %%
keras_word2vec_matrix = textVector.kerasWord2VecEmbedding(google_review_data)

# %%
keras_word2vec_matrix
# Out:
# array([[   0,    0,    0, ..., 1000,  132, 1417],
#        [   0,    0,    0, ...,    1,   32,    1],
#        [   0,    0,    0, ..., 1106,  916,  177],
#        ...,
#        [   0,    0,    0, ...,   41,    5, 2181],
#        [   0,    0,    0, ..., 3528, 2342, 7184],
#        [   0,    0,    0, ...,    2,    4, 1045]], dtype=int32)
